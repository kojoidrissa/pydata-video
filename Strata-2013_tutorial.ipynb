# %%
import pandas as pd

# %%
randn(100)
# Out:
# array([ 0.53143553, -1.16909816, -2.04705476,  0.81110046,  0.1867906 ,
#         0.5584147 ,  0.03456463,  1.61600449,  0.4956988 , -0.19552977,
#        -0.01199576,  0.25469954,  0.4198781 ,  1.14096619,  0.24870501,
#        -0.57611723,  0.53308992, -0.87664832, -1.08262402, -0.10753814,
#         0.70885659, -0.37666059, -1.64889925, -0.08805212, -0.1211312 ,
#         0.40490524, -1.9442231 ,  1.24099278, -0.63753691,  0.23281986,
#         0.62283271,  0.49132463,  0.73155731,  0.32851469,  0.98696929,
#         0.66361226, -0.40426313, -0.65394016,  0.63604997,  1.16088207,
#        -1.90488021,  0.26878729,  1.42930737,  0.78395441, -0.41739207,
#        -1.44299632,  1.49802258,  1.05381829,  0.55500918,  0.83135736,
#         0.82845341,  0.96522598,  0.18928233, -0.38814762,  1.12295026,
#        -1.82419136, -0.55515447,  0.21365494, -0.80724513,  0.04128989,
#         0.07184493, -0.53180126,  1.71226708,  0.22547553, -1.20518305,
# ...

# %%
plot(randn(100))

# %%
import pandas as pd

# %%
randn(100)
# Out:
# array([ 1.35556903,  0.50038482,  0.16761396, -1.3285427 , -0.21989154,
#        -0.94994401, -1.89187551, -0.93931864,  2.21865399,  1.2983779 ,
#        -0.88708981,  0.04297692, -1.11339007,  0.10200909, -0.05212924,
#        -0.966192  ,  0.12416824,  1.85130826, -0.05250966,  0.09240922,
#        -1.12797048, -0.88796939,  0.05805491, -0.51476449, -0.15306211,
#        -1.02039536,  0.24518856, -0.55327004,  0.11440295,  2.61093436,
#        -0.53564513,  3.20822047,  0.05788432,  0.58605532,  1.24819703,
#         0.78906883, -0.69864271,  0.1549237 ,  0.10493714,  0.13739694,
#        -0.79108662, -0.26263403,  0.80540739, -1.23113981,  1.02966809,
#         1.14431895, -0.49676199, -0.50167913,  1.20042986, -0.62042252,
#         0.37415205,  0.54587621,  0.32178748,  0.15382244, -0.50904493,
#        -0.32698281, -1.74730439,  0.00749436,  0.62240128, -1.35373127,
#        -1.19640266, -1.20515371, -0.65930521, -0.51883862,  0.69635525,
# ...

# %%
plot(randn(100))
